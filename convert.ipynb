# %%
import pandas as pd
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
data = pd.read_csv("baseball_data.csv", engine = "python")

data
# Out:
#      Year  Tms  #Bat  BatAge    R/G     G     PA     AB      R      H    2B  \
# 0    2019   30  1287    27.9   4.83  4858  38.39  34.30   4.83   8.65  1.76
# 1    2018   30  1271    28.1   4.45  4862  38.08  34.03   4.45   8.44  1.70
# 2    2017   30  1229    28.3   4.65  4860  38.13  34.07   4.65   8.69  1.73
# 3    2016   30  1247    28.4   4.48  4856  38.01  34.09   4.48   8.71  1.70
# 4    2015   30  1252    28.4   4.25  4858  37.80  34.07   4.25   8.67  1.70
# 5    2014   30  1212    28.5   4.07  4860  37.85  34.08   4.07   8.56  1.67
# 6    2013   30  1202    28.5   4.17  4862  38.02  34.16   4.17   8.66  1.69
# 7    2012   30  1185    28.5   4.32  4860  37.90  34.00   4.32   8.65  1.70
# 8    2011   30  1173    28.7   4.28  4858  38.13  34.11   4.28   8.70  1.73
# 9    2010   30  1157    28.9   4.38  4860  38.18  34.02   4.38   8.76  1.75
# 10   2009   30  1156    28.8   4.61  4860  38.49  34.13   4.61   8.96  1.80
# ...

# %%
fixed_data = data

# %%
fixed_data.dtypes
# Out:
# Year        int64
# Tms         int64
# #Bat        int64
# BatAge    float64
# R/G       float64
# G           int64
# PA        float64
# AB        float64
# R         float64
# H         float64
# 2B        float64
# 3B        float64
# HR        float64
# RBI        object
# SB        float64
# CS        float64
# BB        float64
# SO        float64
# BA        float64
# OBP       float64
# SLG       float64
# OPS       float64
# TB        float64
# GDP       float64
# HBP       float64
# SH        float64
# SF        float64
# IBB       float64
# dtype: object

# %%
fixed_data.loc[(fixed_data.RBI == '--'), 'RBI'] = '0.00'
fixed_data
# Out:
#      Year  Tms  #Bat  BatAge    R/G     G     PA     AB      R      H    2B  \
# 0    2019   30  1287    27.9   4.83  4858  38.39  34.30   4.83   8.65  1.76
# 1    2018   30  1271    28.1   4.45  4862  38.08  34.03   4.45   8.44  1.70
# 2    2017   30  1229    28.3   4.65  4860  38.13  34.07   4.65   8.69  1.73
# 3    2016   30  1247    28.4   4.48  4856  38.01  34.09   4.48   8.71  1.70
# 4    2015   30  1252    28.4   4.25  4858  37.80  34.07   4.25   8.67  1.70
# 5    2014   30  1212    28.5   4.07  4860  37.85  34.08   4.07   8.56  1.67
# 6    2013   30  1202    28.5   4.17  4862  38.02  34.16   4.17   8.66  1.69
# 7    2012   30  1185    28.5   4.32  4860  37.90  34.00   4.32   8.65  1.70
# 8    2011   30  1173    28.7   4.28  4858  38.13  34.11   4.28   8.70  1.73
# 9    2010   30  1157    28.9   4.38  4860  38.18  34.02   4.38   8.76  1.75
# 10   2009   30  1156    28.8   4.61  4860  38.49  34.13   4.61   8.96  1.80
# ...

# %%
fixed_data['RBI'] = fixed_data['RBI'].astype(float)

# %%
fixed_data.dtypes
# Out:
# Year        int64
# Tms         int64
# #Bat        int64
# BatAge    float64
# R/G       float64
# G           int64
# PA        float64
# AB        float64
# R         float64
# H         float64
# 2B        float64
# 3B        float64
# HR        float64
# RBI       float64
# SB        float64
# CS        float64
# BB        float64
# SO        float64
# BA        float64
# OBP       float64
# SLG       float64
# OPS       float64
# TB        float64
# GDP       float64
# HBP       float64
# SH        float64
# SF        float64
# IBB       float64
# dtype: object

# %%
fixed_data.fillna(0.00, inplace = True)

# %%
fixed_data
# Out:
#      Year  Tms  #Bat  BatAge    R/G     G     PA     AB      R      H    2B  \
# 0    2019   30  1287    27.9   4.83  4858  38.39  34.30   4.83   8.65  1.76
# 1    2018   30  1271    28.1   4.45  4862  38.08  34.03   4.45   8.44  1.70
# 2    2017   30  1229    28.3   4.65  4860  38.13  34.07   4.65   8.69  1.73
# 3    2016   30  1247    28.4   4.48  4856  38.01  34.09   4.48   8.71  1.70
# 4    2015   30  1252    28.4   4.25  4858  37.80  34.07   4.25   8.67  1.70
# 5    2014   30  1212    28.5   4.07  4860  37.85  34.08   4.07   8.56  1.67
# 6    2013   30  1202    28.5   4.17  4862  38.02  34.16   4.17   8.66  1.69
# 7    2012   30  1185    28.5   4.32  4860  37.90  34.00   4.32   8.65  1.70
# 8    2011   30  1173    28.7   4.28  4858  38.13  34.11   4.28   8.70  1.73
# 9    2010   30  1157    28.9   4.38  4860  38.18  34.02   4.38   8.76  1.75
# 10   2009   30  1156    28.8   4.61  4860  38.49  34.13   4.61   8.96  1.80
# ...

# %%
fixed_data = fixed_data.drop("R", axis = 1)

# %%
fixed_data.to_csv('baseball_data_altered.csv', index = False, float_format = '%g')
